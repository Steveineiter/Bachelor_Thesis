# %%
import csv

# %% [markdown]
# Load hashtags from csv file and created a dictionary with the hashtag, how often a post included this hashtags and how many likes it has on average.

# %%
def hashtag_to_occurences_and_average_likes():
    # open CSV
    hashtag_to_occurences_and_average_likes = {}

    # TODO add DATE after new crawling
    with open("marry_items.csv", newline="") as marry_csv_file:
        dict_reader = csv.DictReader(marry_csv_file)
        # Put CSV data in dict (ID: liked by)
        for row in dict_reader:
            hashtags = row["hashtags_of_post"].split()
            likes = row["likes_of_post"]

            for hashtag in hashtags:
                hashtag = "".join((filter(str.isalnum, hashtag)))
                if "#" + hashtag in hashtag_to_occurences_and_average_likes.keys():
                    hashtag_to_occurences_and_average_likes["#" + hashtag][0] += 1
                    if not likes:
                        likes = 0
                    hashtag_to_occurences_and_average_likes["#" + hashtag][1] = int(hashtag_to_occurences_and_average_likes["#" + hashtag][1]) + int(likes)
                else:
                    if not likes:
                        likes = 0
                    hashtag_to_occurences_and_average_likes["#" + hashtag] = [1, likes]
    print("Hashtags   |    number of posts with this hashtag    | likes  ")
    for key, data in hashtag_to_occurences_and_average_likes.items():
        used_in_posts, likes = data
        print(key, " " * 5, used_in_posts, " " * 5, likes, " " * 5)
    return hashtag_to_occurences_and_average_likes

# %% [markdown]
# Fucntion to safe data in csv.

# %%
def safe_data_in_csv(hashtag_to_occurences_and_average_likes):
    with open("hashtags_likes_correlation.csv", "w", newline="") as hashtags_likes_correlation_csv_file:
        fieldnames = ["hashtag", "average_likes", "number_of_posts_with_this_hashtag"]
        dict_writer = csv.DictWriter(
            hashtags_likes_correlation_csv_file, fieldnames=fieldnames
        )

        dict_writer.writeheader()
        for (
                hashtag,
                data,
        ) in hashtag_to_occurences_and_average_likes.items():
            number_of_posts_with_this_hashtag, likes = data
            average_likes = int(likes) / number_of_posts_with_this_hashtag
            dict_writer.writerow(
                {
                    "hashtag": hashtag,
                    "average_likes": average_likes,
                    "number_of_posts_with_this_hashtag": number_of_posts_with_this_hashtag,
                }
            )

# %% [markdown]
# Call the previously defined funcitons.

# %%
safe_data_in_csv(hashtag_to_occurences_and_average_likes())
# Out:
# Hashtags   |    number of posts with this hashtag    | likes
# #haidi       5       559
# #throwback       7       529
# #sommersonnesonnenschein       1       108
# #cocktailtime       5       484
# #drinks       49       5507
# #drinkdifferent       56       6282
# #regionalität       48       5357
# #vodka       7       755
# #plastikfrei       45       4958
# #nachhaltigkeit       18       1618
# #vegan       44       4665
# #österreich       58       6490
# #steiermark       64       7016
# #eistee       68       8261
# #icetea       37       4277
# #beeren       40       4686
# #getränke       16       1626
# #genuss       17       1773
# #gönnen       8       694
# #trinken       55       6247
# #frisch       18       1554
# #erfrischung       66       7419
# #durstlöscher       48       5618
# #durst       46       5341
# #marryicetea       42       4877
# #youngandurban       20       2757
# #startup       53       5797
# #natureistee       18       2437
# #regional       31       4012
# #steirischebeeren       4       361
# #schnee       1       100
# #beerigeweihnachten       1       100
# #weihnachtszauber       1       100
# #weihnachten2020       1       100
# #fotoderwochegraz       1       100
# #spaß       3       211
# #Prototypen       1       60
# #marry       19       2029
# #messestandes       1       60
# #einfach       1       60
# #wohnzimmerflair       1       60
# #zaubern       1       60
# #fs19       1       60
# #festival       1       60
# #business       3       275
# #concepting       1       60
# #startupbusiness       23       2616
# #startuplife       39       4157
# #motivation       30       3612
# #unternehmertum       25       2905
# #wertschätzung       47       5271
# #regionaleprodukte       46       5445
# #regionales       38       4505
# #nachhaltigeprodukte       31       3711
# #umwelt       27       3167
# #verantwortung       27       3167
# #gemeinschaft       33       3956
# #erfrischunggestränk       32       3849
# #drinkstagram       36       4245
# #drinkhealthy       39       4769
# #graz       99       11606
# #igersgraz       68       8129
# #rot       1       118
# #leidenschaft       1       118
# #coloroflove       1       118
# #red       1       118
# #redismycolor       1       118
# #getränk       6       653
# #frische       1       118
# #eisteeliebe       1       118
# #beerenliebe       13       1491
# #tealovers       4       424
# #vegandrink       7       747
# #tealife       3       273
# #teaforlife       2       273
# #relax       7       822
# #localdrink       4       495
# #instatea       3       345
# #softdrink       2       273
# #instagraz       9       1145
# #instaaustria       8       1017
# #igersaustria       14       1742
# #styria       13       1496
# #drinkmarry       1       71
# #marryme       13       1484
# #bemymarry       2       533
# #mate       10       1114
# #rotbusch       5       810
# #matetea       3       226
# #beerig       13       1118
# #marrytheberriedicetea       1       71
# #local       16       1996
# #steirisch       28       3461
# #kino       1       71
# #cinema       1       71
# #glücksgefühle       2       132
# #love       2       71
# #liebe       1       71
# #kribbeln       1       71
# #couple       2       132
# #verlieben       1       71
# #schmetterlingeimbauch       1       71
# #kinoliebe       1       71
# #ersteberührung       1       71
# #loveatthefirsttouch       1       71
# #schubertkino       1       71
# #schubertkinograz       1       71
# #staytuned       7       517
# #newproduct       2       0
# #exciting       3       0
# #newin       4       179
# #soon       1       0
# #drink       13       1048
# #newdrink       6       274
# #summer       5       335
# #summerdrink       11       593
# #sommergetränk       7       449
# #zischfrisch       4       0
# #spritzig       5       96
# #spritzigemomente       1       0
# #regionalebeeren       5       1009
# #matetee       2       359
# #rotbuschtee       3       444
# #tierisch       1       359
# #lecker       6       803
# #eiskalt       2       515
# #kleschkalt       1       359
# #youngandurbanbyspar       15       2254
# #katze       1       359
# #cat       1       359
# #katzenreich       1       359
# #bookworm       1       106
# #igreads       1       106
# #booksbooksbooks       1       106
# #booktube       1       106
# #buchtipp       1       106
# #bookstagrammers       1       106
# #bookoftheday       1       106
# #readerlife       1       106
# #buchempfehlung       1       106
# #buchliebe       1       106
# #bücherliebe       1       106
# #lesen       2       212
# #leseliebe       1       106
# #frühlingsanfang       1       106
# #derfrühlingkommt       1       106
# #märz       1       106
# #schönertag       1       106
# #wettergenießen       1       106
# #grazgram       7       872
# #igdaily       7       899
# #event       1       155
# #fachl       1       99
# #tee       5       754
# #neuesjahr       1       99
# #jahr2020       1       99
# #community       3       374
# #genießer       1       99
# #eisteefreunde       1       99
# #app       1       69
# #happycow       1       69
# #vegetarische       1       69
# #vegane       1       69
# #restaurants       1       69
# #veganlovers       1       69
# #vegetarisch       1       69
# #vegetarian       1       69
# #vegandeutschland       1       69
# #veganaustria       3       221
# #veganbreakfast       1       69
# #veganfoodspot       1       69
# #carry       9       1187
# #neu       3       473
# #carryicetea       11       1313
# #zitroneneistee       3       507
# #holunder       11       1441
# #klassisch       1       161
# #extravagant       1       161
# #erfrischen       1       161
# #frühling       8       855
# #zufriedenheit       1       72
# #zufriedenundglücklich       1       72
# #energietanken       1       72
# #glücksmomente       1       72
# #erfrischend       5       535
# #urbandrinks       10       844
# #gönnung       7       860
# #fruchtig       8       938
# #schmecktgut       2       72
# #drinkathome       2       72
# #kauftlokal       1       72
# #lieferung       1       72
# #abholen       1       72
# #kontaktlos       1       72
# #istagraz       1       72
# #Graz       2       105
# #popupstore       1       62
# #trinkkultur       1       62
# #refreshlend       1       62
# #megafein       1       65
# #skirennläuferin       1       65
# #tbt       4       255
# #verrücktnachmarry       37       3184
# #vollfein       26       1958
# #supportyourlocal       6       668
# #wirschaffendas       3       339
# #passtaufeuchauf       3       339
# #zusammenhalt       6       575
# #zusammensindwirstark       3       339
# #kaufregional       1       90
# #kauflokal       3       339
# #kaufingraz       3       339
# #kaufinösterreich       1       90
# #lokaleinkaufen       3       339
# #regionaleinkaufen       2       218
# #erfrischungsgetränk       5       649
# #natürlich       7       618
# #nachhaltig       1       90
# #nachhaltigleben       1       90
# #sportlich       3       399
# #zielstrebig       2       269
# #selbstständig       1       124
# #wakeboarding       1       124
# #wakeboard       1       124
# #sport       1       124
# #lakelife       1       124
# #wakeboarder       1       124
# #wakeboardaustria       1       124
# #wakelife       1       124
# #board       1       124
# #Gewinnspiel       2       297
# #pokebowl       1       126
# #foodgraz       1       126
# #gesundeernährung       1       126
# #gesundessen       1       126
# #gesundebowls       1       126
# #gin       6       534
# #ginoclock       2       243
# #ginlovers       3       331
# #gintonicday       1       130
# #coctailtime       1       130
# #feierabend       1       130
# #abschaltenundgeniessen       3       220
# #Restaurant       2       125
# #Gastgarten       1       63
# #regionalen       1       63
# #Mittagsgericht       1       63
# #Gemüse       1       63
# #Garten       1       63
# #Sozialunternehmen       1       63
# #Österreich       1       63
# #Werten       1       63
# #Gleichberechtigung       1       63
# #Produkten       1       63
# #entrepreneurship       4       433
# #support       1       63
# #zusammen       1       63
# #inklusion       2       151
# #danke       1       63
# #wanderlust       2       232
# #wandern       2       232
# #wandernmachtglücklich       3       232
# #pausemachen       1       90
# #chillmodus       1       90
# #natur       8       751
# #retreat       1       90
# #koffeinfrei       2       180
# #marrykida       1       81
# #kids       2       180
# #familie       1       81
# #family       2       81
# #muttertag       2       167
# #weltfototag       1       57
# #fotografie       1       57
# #archiv       1       57
# #fotoshooting       1       57
# #foto       2       109
# #worldphotoday       1       57
# #nostalgie       3       190
# #schnappschuss       1       57
# #snapshot       1       57
# #drinkglobalactlocal       1       39
# #crowdfunding       8       629
# #growth       2       165
# #entrepreneurlife       2       187
# #rollout       2       167
# #crowdsupport       2       167
# #marrynews       3       256
# #goodnews       1       105
# #comingsoon       3       312
# #comingup       2       312
# #ankündigung       2       312
# #einfachlecker       2       312
# #ohnezusatzstoffe       1       105
# #natürlichlecker       1       105
# #madeinaustria       6       583
# #austria       3       349
# #Marry       2       136
# #wochenende       3       264
# #wodka       6       647
# #handgefertigt       1       80
# #bioprodukte       1       80
# #gönndir       2       166
# #song       1       0
# #abwinken       1       0
# #soundon       1       0
# #geschmack       1       0
# #vegandrinks       8       961
# #himbeeren       13       1537
# #brombeeren       7       761
# #österreichischequalität       6       665
# #stayhome       2       203
# #staysafe       2       203
# #breakfastmostimportantmeal       1       96
# #breakfastgoals       1       96
# #breakfastporn       1       96
# #breakfastinspiration       1       96
# #frühstück       3       307
# #frühstücksideen       1       96
# #frühstücksliebe       1       96
# #frühstücken       1       96
# #gesundesfrühstück       1       96
# #gutenappetit       1       96
# #essenmachtglücklich       1       96
# #brunchen       2       182
# #grazbrunch       1       96
# #dubistsograz       2       224
# #grazfood       3       335
# #grazfoodie       1       96
# #foodiegraz       1       96
# #grazeats       1       96
# #iggraz       2       224
# #instagrazer       1       96
# #miteinanderstattgeneinander       1       107
# #makeanimpact       1       107
# #igers       3       328
# #onlineshop       1       107
# #stayathome       1       107
# #shoppingtime       1       107
# #instapic       1       107
# #bio       5       492
# #sommer       11       991
# #marryvorrat       1       91
# #madeinstyria       2       152
# #elderflower       4       425
# #zitrone       10       1289
# #rooibos       3       251
# #icedtea       2       152
# #veganereistee       2       152
# #veggie       3       271
# #2min2mio       3       318
# #herrengasse       2       152
# #spar       8       1165
# #happyeaster       2       288
# #easterbasket       1       128
# #ostern2020       1       128
# #froheostern       1       128
# #ostern       3       342
# #osterhase       1       128
# #hase       2       288
# #osterzeit       1       128
# #osternkannkommen       1       128
# #feiertage       1       128
# #osterwochenende       1       128
# #ostergeschenke       1       128
# #ostergeschenkidee       1       128
# #geschenkideen       1       128
# #freudeschenken       2       341
# #überraschung       2       257
# #vonherzen       1       128
# #sunnyday       1       128
# #sunshine       1       128
# #teatime       2       155
# #urbandrink       8       751
# #refreshingdrink       3       306
# #healthylifestyle       2       155
# #beverage       2       151
# #alkoholfrei       2       122
# #zumwohl       1       0
# #himbeere       2       151
# #partner       1       64
# #ingredients       1       64
# #vintage       1       64
# #entrepreneurspirit       1       64
# #startupfeeling       1       64
# #startuplifestyle       7       891
# #tabledecoration       1       64
# #splishsplash       1       49
# #einfachso       1       49
# #instaphoto       1       49
# #berriedicetea       10       483
# #marrycrew       8       970
# #visionary       1       89
# #sippidance       1       89
# #positivevibes       1       89
# #entrepreneurs       3       326
# #workhard       3       326
# #bestteamever       2       208
# #teamgoals       4       326
# #awesometeam       3       326
# #bepassionate       3       326
# #newemployee       3       326
# #welcometotheteam       3       326
# #newhire       3       326
# #loveyourjob       3       326
# #workfun       3       326
# #newjob       3       326
# #marketing       4       411
# #socialmediaqueen       3       326
# #igersstyria       3       326
# #oliver       1       51
# #tray       1       51
# #marrys       2       103
# #wiener       1       51
# #marryfan       1       51
# #unterstützung       1       51
# #startupfans       1       51
# #urbanlovers       1       51
# #blacktea       1       114
# #ceylon       4       543
# #elder       3       453
# #lemon       3       387
# #kunsthaus       2       327
# #kunsthauscafé       1       114
# #kunsthauscafegraz       1       114
# #kunsthauscafémeetscarry       1       114
# #schwarztee       3       487
# #zitronig       2       197
# #cheers       5       384
# #genussreich       1       114
# #bestdrink       2       304
# #genießen       5       738
# #partnerschaft       1       114
# #verrucktnachmarry       3       215
# #marrygoesspar       1       0
# #unternehmentum       3       264
# #marryist       1       104
# #puzzle       1       104
# #garry       3       227
# #biogin       1       96
# #steirischergin       1       96
# #steirischerbiogin       1       96
# #marrygin       3       227
# #handarbeit       1       96
# #handgrafted       1       96
# #handgraftedgin       1       96
# #aeijst       1       96
# #region       3       352
# #geschmackserlebnis       1       96
# #garrymeetsmarry       1       96
# #nature       1       103
# #spring       1       103
# #huihuihui       1       48
# #freitag       2       115
# #ichsehevierdavon       1       48
# #clone       1       48
# #cloneshot       1       48
# #lowsugar       3       339
# #foodstagram       2       260
# #teaaddict       1       155
# #springfeeling       1       155
# #schlossberg       1       67
# #roiboos       1       67
# #2min2mil       5       440
# #dankeschön       1       70
# #vierbeiner       1       70
# #qualität       1       70
# #pre       1       70
# #videoshooting       1       70
# #communitymatters       1       70
# #localdrinks       3       293
# #fasching       1       74
# #fasching2012       1       74
# #johanisbeeren       2       192
# #news       2       156
# #launch       1       0
# #tasty       2       0
# #colddrinks       1       0
# #newcomer       1       0
# #grazerdrink       1       0
# #gettogether       1       0
# #localbusiness       1       0
# #Gaumenfreude       1       0
# #bestergeschmack       1       0
# #zischfrischamtisch       2       96
# #süffig       1       0
# #spritzigeMomente       1       0
# #urleiwand       1       0
# #bewegungohnebewegung       1       0
# #stilllifephotography       1       0
# #cinemagraph       1       0
# #augartenpark       1       0
# #augarten       1       0
# #frischeluft       1       0
# #goldenestunde       1       0
# #koffeinfreiemarry       1       99
# #sonne       2       195
# #beerige       1       99
# #familiengetränk       1       99
# #berries       2       204
# #werte       2       107
# #nachhaltigerleben       2       107
# #netzwerk       2       107
# #persönlichkeit       2       107
# #transparenz       2       107
# #digitalisierung       3       226
# #zukunft       3       249
# #tgif       1       37
# #veganicetea       1       37
# #tgifriday       1       37
# #tgifridays       1       37
# #feierabendlaune       1       37
# #weekendvibes       1       37
# #innovationrocks       1       37
# #sommerliebe       1       61
# #liebeaufdenerstenschluck       2       523
# #staymarry       1       155
# #mondaymotivation       1       155
# #mondayfunday       1       155
# #mondaymantra       1       155
# #teammeeting       1       155
# #teamwork       1       155
# #weeklygoals       1       155
# #entreprenership       2       274
# #entreprenerugoals       2       274
# #ziele       4       584
# #ehrgeiz       3       455
# #motiviert       4       584
# #unternehmen       2       274
# #losgehts       2       382
# #wochenstart       1       155
# #machdeinding       3       403
# #montagsmotivation       1       155
# #teammarry       1       155
# #dowhatyoulove       1       119
# #passionatefoodie       1       119
# #gewinnspiel       3       558
# #pipapo       1       162
# #gutscheine       1       162
# #gewinnen       1       162
# #yougandurbanbyspar       1       162
# #thinkpositive       1       43
# #photooftheday       1       43
# #lachenistgesund       1       43
# #laugh       1       43
# #herbstfrisch       1       43
# #fall       1       43
# #wetterfotografie       1       43
# #picoftheday       2       122
# #friends       1       43
# #balkonien       1       112
# #balkonliebe       1       112
# #aijst       1       55
# #summerfeeling       1       55
# #enjoylife       1       55
# #pinkdrink       1       55
# #lovely       1       55
# #ginmarry       2       129
# #throwbackThursday       2       97
# #crowdacademy       1       52
# #lastyear       1       52
# #win       3       595
# #holypit       1       199
# #naturdeo       1       199
# #straden       2       565
# #beerenkuss       2       462
# #beerengenuss       1       462
# #chillmoduson       1       133
# #stadpark       1       133
# #gemeinsam       5       653
# #freundschaft       2       214
# #freunde       3       268
# #lieblingsmensch       1       133
# #chillmodusaktiviert       1       133
# #marryeaster       1       160
# #frohe       1       160
# #marrycation       1       142
# #goexplore       1       142
# #instatravel       1       142
# #travelbug       1       142
# #landscape       1       142
# #travelgram       1       142
# #travelphotography       1       142
# #mountainsarecalling       1       142
# #mountainescapes       1       142
# #austrianalps       1       142
# #loveaustria       1       142
# #lakeview       1       142
# #berge       1       142
# #bergliebe       1       142
# #bergpanorama       1       142
# #naturgenießen       1       142
# #wanderliebe       1       142
# #dahoam       1       142
# #upperaustria       1       142
# #oberösterreich       1       142
# #kleinersonnstein       1       142
# #traunsee       1       142
# #spontan       1       130
# #lebhaft       1       130
# #communitylove       1       130
# #wertschatzung       1       130
# #regionaleproduktemachenglucklich       1       130
# #osterreich       1       130
# #gemeinsamstark       3       404
# #trinkenhilft       1       130
# #durstloscher       1       130
# #herbstliebe       3       347
# #herbst       3       347
# #herbstfarben       3       347
# #herbstlich       3       347
# #herbstzeit       3       347
# #naturbelassen       4       347
# #teetrinken       3       347
# #teelicious       3       347
# #teeliebe       3       347
# #teelovers       3       347
# #erinnerung       2       249
# #abstandhalten       2       249
# #rücksicht       2       249
# #zusammenhalten       2       249
# #füreinander       2       249
# #haltetdurch       2       249
# #supporteachother       2       249
# #gangl       1       103
# #munter       1       103
# #muntermacher       1       103
# #carrymehome       1       98
# #gemeinsamgenießen       1       98
# #mothersday       1       86
# #muttertagsgeschenk       1       86
# #mutterliebe       1       86
# #mütter       1       86
# #sunday       1       86
# #subdayvibes       1       86
# #sonntag       1       86
# #sonntagsmodus       1       86
# #brunch       2       299
# #brunchtime       1       86
# #brunchideas       1       86
# #brunchathome       1       86
# #gönndirwas       1       86
# #proud       1       207
# #excited       1       207
# #unterwegs       1       207
# #aufdemweg       1       207
# #sparoesterreich       1       207
# #interspar       1       207
# #esgehtwiederlos       1       207
# #vorfreudeistdieschönstefreude       1       207
# #genussmomente       1       207
# #cocktail       3       117
# #summervibes       5       273
# #regionalereistee       2       304
# #bemarry       1       114
# #fröhlich       1       73
# #gründer       1       73
# #david       1       73
# #felber       1       73
# #schokolade       1       73
# #sorten       1       73
# #schoki       1       73
# #sweettooth       1       73
# #leckerschmecker       1       73
# #dessertoftheday       1       73
# #marryxoxo       1       73
# #chocolateheaven       1       73
# #aeijstgin       2       201
# #ginliebe       1       113
# #ginlicious       1       113
# #prost       2       209
# #branding       1       142
# #campaign       1       142
# #team       2       227
# #ergebnis       1       142
# #illustrations       1       142
# #argentinische       1       142
# #tradition       1       142
# #Matetee       1       142
# #ursprungsland       1       142
# #flasche       1       142
# #erlebnis       1       142
# #crowdfundingcampaign       1       142
# #corporatedesign       1       142
# #drinklovers       3       286
# #enterpreneurs       2       196
# #puls4       1       227
# #startupshow       1       227
# #startups       1       227
# #milestones       1       227
# #tvshow       1       227
# #medien       1       227
# #fernsehen       1       227
# #vorschau       1       227
# #bühne       1       227
# #bignews       1       227
# #startupstory       5       564
# #entrepreneurialspirit       1       227
# #businessgrowth       1       227
# #wien       2       315
# #vienna       2       281
# #igerswien       1       227
# #igersvienna       1       227
# #carrymeetsspar       1       156
# #carryimspar       1       156
# #SPAR       1       156
# #SPARösterreich       1       156
# #zitronigsüß       1       156
# #erfischungsgetränk       1       156
# #regionalergenuss       2       346
# #grazerstartup       1       156
# #grazereistee       2       239
# #sparösterreich       3       344
# #sparmeetsmarryicetea       1       71
# #lifestyle       1       71
# #grazericetea       1       71
# #healthyicetea       1       71
# #goodvibes       2       71
# #shopping       1       71
# #sheraton       2       150
# #müllerdrogerie       1       75
# #dm       1       75
# #rossmann       1       75
# #kaufland       1       75
# #pitchperfect       1       75
# #foodandbeverage       1       75
# #infoodwetrust       1       75
# #inbeverageweenjoy       1       75
# #frankfurt       1       75
# #freundesprüche       1       81
# #quotes       2       158
# #zitateundsprüche       1       81
# #zitatefürsleben       1       81
# #spruch       1       81
# #reginalität       1       81
# #throwbackthursday       1       79
# #polaroids       1       79
# #partys       1       76
# #geburtstagen       1       76
# #mixgetränk       1       76
# #südsteiermark       1       76
# #kooperation       1       76
# #spirituosen       1       76
# #marryaperitif       1       0
# #aperitif       1       0
# #apéritif       1       0
# #apéritiftime       1       0
# #sommeraperitif       1       0
# #beerigeraperitif       1       0
# #selfmade       1       0
# #selfmadeaperitif       1       0
# #regionaleraperitif       1       0
# #klassischeraperitiv       1       0
# #aperitifcocktails       1       0
# #süßeraperitiv       1       0
# #erfischend       1       0
# #feiern       1       0
# #gartenparty       1       0
# #grillabend       1       0
# #mixing       1       0
# #cocktailmixing       1       0
# #marrymixing       1       0
# #rezepte       1       0
# #aperitifrezept       1       0
# #bestaperitif       1       0
# #doityourself       1       0
# #haidiwodka       1       97
# #heu       1       97
# #heuwodka       2       189
# #biowodka       2       189
# #biovodka       2       189
# #premiumwodka       1       97
# #premiumvodka       1       97
# #naturlicherwodka       1       97
# #steirischegraser       2       189
# #heuaromen       1       97
# #weihachtsgeschenk       1       97
# #gründermesse       1       97
# #whatchado       1       97
# #startupscene       2       160
# #entrepreneurgoals       2       185
# #founderandfriends       1       97
# #workaholic       1       134
# #empathisch       1       134
# #herzundseele       1       134
# #alwaysfresh       1       134
# #cocacola       1       134
# #whywhywhy       1       134
# #abenteuerlustig       1       145
# #megasympathisch       1       145
# #dasalzburger       1       163
# #jahr       1       0
# #weihnachtsfest       1       0
# #rutsch       1       0
# #2020       1       0
# #highlights       1       0
# #christmas       1       0
# #xmas       1       0
# #christmasiscoming       1       0
# #instagood       1       0
# #vielendank       1       0
# #merrychristmas       1       0
# #marrychristmas       1       0
# #bestteam       1       142
# #marryontour       1       142
# #deinkhealthy       1       142
# #eis       1       89
# #eisgehtimmer       1       89
# #konditorei       1       89
# #eisliebe       1       89
# #eisessen       1       89
# #refresh       1       0
# #gettoknowmarry       1       107
# #unternehmenskultur       1       107
# #herbst202       1       114
# #sparmeetscarry       2       273
# #SriLanka       1       190
# #lieblingseistee       1       190
# #gaumenfreude       3       286
# #wieallesbegann       1       68
# #marryorigins       1       68
# #probierengehtüberstudieren       1       68
# #erfinder       1       61
# #geburtstag       1       61
# #überraschungsparty       1       61
# #entrepreneur       1       61
# #bdayparty       1       61
# #suprisebirthday       1       61
# #officeparty       1       61
# #sohn       1       56
# #Curry       2       115
# #Fotos       1       56
# #sharingiscaring       1       56
# #healthy       1       56
# #healthyfood       1       56
# #fresh       1       83
# #iceteas       1       83
# #icetealemon       1       83
# #iceteatime       1       83
# #Asia       1       62
# #Fusion       1       62
# #Sushi       1       62
# #Thai       1       62
# #Mongolian       1       62
# #Teppanyaki       1       62
# #Unterstützern       1       62
# #truefellas       1       74
# #barbershop       1       74
# #verkostung       3       304
# #valentinesday       1       300
# #valentine       1       300
# #berry       1       300
# #bemyvalentine       1       300
# #seidgespannt       2       234
# #baldgehtslos       1       129
# #wirfreuenuns       1       129
# #meilensteine       1       129
# #erfolg       1       129
# #neues       1       129
# #disziplin       1       129
# #zieleverfolgen       1       129
# #durchstarten       1       129
# #bestesteam       2       310
# #aufgeregt       1       129
# #geheimnis       1       129
# #geheimnisse       1       129
# #freude       2       342
# #Marrycrew       1       181
# #ambitioniert       1       181
# #gesprächig       1       181
# #abenteuerreich       1       181
# #Festival       1       63
# #Outfit       1       63
# #dressup       1       63
# #fashiontrends       1       63
# #lifeisapitch       1       119
# #growthmindset       1       119
# #lieblingsfoto       1       48
# #artsy       1       118
# #ehrgeizig       1       118
# #essensliebhaberin       1       118
# #teamvorstellung       1       118
# #energiebündel       1       118
# #spreadhappiness       1       118
# #nocringe       1       118
# #promotion       1       52
# #lokalen       1       52
# #promotiongirl       1       52
# #fashionpost       1       52
# #fashiongram       1       52
# #instastyle       1       52
# #natürlichgesund       1       91
# #umweltbewusst       1       127
# #beerenentsaften       1       127
# #tealoversofinstagram       1       127
# #popupstores       1       45
# #wahrelieberostetnicht       1       45
# #ideentriebwerkgraz       1       45
# #startupspritzer       1       45
# #daslebengenießen       1       45
# #25grams       1       45
# #kakaolimonade       1       45
# #urbanlifestyle       1       115
# #supportsmallbusiness       1       115
# #brandsyoulove       1       115
# #havingfun       1       115
# #fundays       1       115
# #networkingday       1       115
# #kunsthausgraz       1       115
# #kunsthauscafe       2       328
# #grazfoodguide       1       115
# #veranstaltung       1       115
# #erinnerungen       1       115
# #WOW       1       59
# #Flaschen       1       59
# #Franchisekette       1       59
# #Partner       1       59
# #Gutscheine       1       59
# #Gewinn       1       59
# #theberriedicetea       1       59
# #larry       2       96
# #marrymeetsbeer       2       96
# #lavabräu       2       96
# #marrymeetslavabräu       1       96
# #prickeln       1       96
# #sprudel       1       96
# #bierig       2       96
# #beerigbierig       1       96
# #momente       1       96
# #colddrink       1       96
# #drinkbythepool       1       96
# #urlaubsfeeling       1       96
# #steirische       1       85
# #happybirthday       1       73
# #einjahrälter       1       73
# #kuss       1       0
# #youngandurbbyspar       1       0
# #himbeerenliebe       1       127
# #naschen       1       127
# #früchte       2       241
# #mondayisfunday       1       79
# #einbisschenspassmusssein       1       79
# #montage       1       79
# #gehtsichaus       1       79
# #zirtronen       1       105
# #icetealover       1       105
# #veganfood       1       105
# #drinklocal       2       176
# #foodlover       1       105
# #ganzebeeren       1       73
# #johannisbeeren       1       73
# #gelernt       1       81
# #gewachsen       1       81
# #curiosity       1       81
# #regionale       1       81
# #limitierte       1       81
# #fruhstuck       1       213
# #breakfast       1       213
# #kaffee       1       213
# #food       1       213
# #gutenmorgen       1       213
# #weihnachtsgeschenk       1       213
# #Genuss       1       213
# #Kostlichkeiten       1       213
# #Regionalitat       1       213
# #verrücktnachlarry       2       0
# #zischfrischlarry       1       0
# #nowavailable       1       0
# #Pizzen       1       57
# #Calamaries       1       57
# #solecker       1       57
# #pizzagourmet       1       57
# #foodporn       1       57
# #gastro       1       57
# #supporter       1       57
# #sogood       1       57
# #fifteensecondsfestival       1       81
# #feedback       1       81
# #prelaunch       1       81
# #startupland       1       81
# #innovation       1       81
# #kreativität       1       81
# #stadtgraz       1       81
# #thinkahead19       1       81
# #marrygoesCrowdfunding       1       81
# #bioheuwodka       1       92
# #grunerwodka       1       92
# #buro       1       84
# #office       1       84
# #arbeitswoche       1       84
# #entspannt       1       151
# #igdrinks       1       151
# #cooldrinks       1       151
# #veganfindsaustria       1       151
# #socialbusiness       1       88
# #kunst       1       88
# #design       1       88
# #kunstkenntkeinegrenzen       1       88
# #voifesch       1       88
# #bewusstseinsbildung       1       88
# #rewards       1       88
# #Kaffeekultur       1       54
# #barista       1       54
# #coffeeshop       1       54
# #baristagram       1       54
# #beerenstark       1       114
# #Gin       1       88
# #schnapsbrennen       1       88
# #herzblut       1       88
# #workshops       1       88
# #ginandmarry       1       88
# #garrytheberriedgin       1       88
# #experiments       1       88
# #foundersday       1       88
# #sweet       1       77
# #süßeverführung       1       77
# #baldistessoweit       1       105
# #marrycocktail       1       0
# #berryspirit       1       0
# #delicious       1       145
# #tastethefeeling       1       145
# #togetherisbetter       1       145
# #holunderblüten       1       183
# #zitronigfrisch       1       183
# #vielglück       1       183
